# %%
from fastmcp import FastMCP

mcp = FastMCP("演示 🚀")

@mcp.tool
def add(a: int, b: int) -> int:
    """两数相加"""
    return a + b


mcp.run()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 11
#       7     """两数相加"""
#       8     return a + b
#       9
#      10
# ---> 11 mcp.run()
#
# File /opt/miniconda3/lib/python3.13/site-packages/fastmcp/server/mixins/transport.py:91, in TransportMixin.run(self, transport, show_banner, **transport_kwargs)
#      77 def run(
#      78     self: FastMCP,
#      79     transport: Transport | None = None,
#      80     show_banner: bool | None = None,
#      81     **transport_kwargs: Any,
#      82 ) -> None:
#      83     """Run the FastMCP server. Note this is a synchronous function.
#      84
#      85     Args:
#    (...)     88             FASTMCP_SHOW_SERVER_BANNER setting (default: True).
#      89     """
# ---> 91     anyio.run(
#      92         partial(
#      93             self.run_async,
#      94             transport,
# ...
